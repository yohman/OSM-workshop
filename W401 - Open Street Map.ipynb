# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Take-notice!" data-toc-modified-id="Take-notice!-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Take notice!</a></span></li><li><span><a href="#Open-Street-Map" data-toc-modified-id="Open-Street-Map-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Open Street Map</a></span><ul class="toc-item"><li><span><a href="#Download-visualizing-Open-Street-Map-data" data-toc-modified-id="Download-visualizing-Open-Street-Map-data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Download visualizing Open Street Map data</a></span></li><li><span><a href="#Import-the-libraries" data-toc-modified-id="Import-the-libraries-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Import the libraries</a></span></li><li><span><a href="#Define-an-area-of-interest" data-toc-modified-id="Define-an-area-of-interest-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Define an area of interest</a></span></li><li><span><a href="#Be-careful!" data-toc-modified-id="Be-careful!-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Be careful!</a></span></li><li><span><a href="#Eliminate-unnecessary-columns" data-toc-modified-id="Eliminate-unnecessary-columns-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Eliminate unnecessary columns</a></span></li></ul></li><li><span><a href="#Make-a-building-type-chart" data-toc-modified-id="Make-a-building-type-chart-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Make a building type chart</a></span><ul class="toc-item"><li><span><a href="#Count-the-unique-buildings" data-toc-modified-id="Count-the-unique-buildings-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Count the unique buildings</a></span></li><li><span><a href="#Create-a-dataframe-from-value-counts" data-toc-modified-id="Create-a-dataframe-from-value-counts-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Create a dataframe from value counts</a></span></li><li><span><a href="#Renaming-columns" data-toc-modified-id="Renaming-columns-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Renaming columns</a></span></li><li><span><a href="#Create-a-horizontal-bar-chart" data-toc-modified-id="Create-a-horizontal-bar-chart-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Create a horizontal bar chart</a></span></li><li><span><a href="#Sorting-a-dataframe" data-toc-modified-id="Sorting-a-dataframe-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Sorting a dataframe</a></span></li></ul></li><li><span><a href="#Geopandas-Map-Plots" data-toc-modified-id="Geopandas-Map-Plots-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Geopandas Map Plots</a></span><ul class="toc-item"><li><span><a href="#Color-coding-buildings" data-toc-modified-id="Color-coding-buildings-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Color coding buildings</a></span></li><li><span><a href="#Clean-up:-Add-a-title,-move-the-legend,-remove-axis" data-toc-modified-id="Clean-up:-Add-a-title,-move-the-legend,-remove-axis-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Clean up: Add a title, move the legend, remove axis</a></span><ul class="toc-item"><li><span><a href="#Move-the-legend" data-toc-modified-id="Move-the-legend-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Move the legend</a></span></li><li><span><a href="#Remove-the-legend's-border" data-toc-modified-id="Remove-the-legend's-border-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Remove the legend's border</a></span></li><li><span><a href="#Add-a-title" data-toc-modified-id="Add-a-title-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Add a title</a></span></li><li><span><a href="#Remove-the-axis" data-toc-modified-id="Remove-the-axis-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Remove the axis</a></span></li></ul></li><li><span><a href="#Add-a-basemap" data-toc-modified-id="Add-a-basemap-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Add a basemap</a></span></li></ul></li><li><span><a href="#Create-a-function" data-toc-modified-id="Create-a-function-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Create a function</a></span></li><li><span><a href="#Looping-through-it" data-toc-modified-id="Looping-through-it-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Looping through it</a></span></li><li><span><a href="#Doing-other-searches" data-toc-modified-id="Doing-other-searches-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Doing other searches</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-danger">
#
# <h1>Take notice!</h1>
# <ul>
#     <li>This session will be recorded</li>
# </ul>
#
# </div>

# %% [markdown]
# # Open Street Map
#
# In this lab, you will learn how to:
# * use various python libraries to search for and download Open Street Map *building* data
# * categorize buildings by type
# * visualize buildings on a map
# * create a function to produce building maps
# * create a loop to produce building maps for multiple locations
#
# Note that we will learn how to use street network analysis with OSMnx in subsequent labs.

# %% [markdown]
# What is open street map?
# - https://www.openstreetmap.org/
#
# OSMnx
# - library documentation (https://osmnx.readthedocs.io)
# - github (https://github.com/gboeing/osmnx)
# - Examples and demos are available at: https://github.com/gboeing/osmnx-examples
#
# Contextily
# - https://github.com/geopandas/contextily

# %% [markdown]
# ## Download visualizing Open Street Map data
#
# OSMnx lets you download data from Open Street Map.
#
# You can download OSM data by providing OSMnx any of the following:
#   - a bounding box
#   - a lat-long point plus a distance
#   - an address plus a distance
#   - a place name or list of place names (to automatically geocode and get the boundary of)
#   - a polygon of the desired street network's boundaries
#   - a .osm formatted xml file

# %% [markdown]
# For the sake of clarity, and effective use of a workshop setting, let's use the "address plus a distance" method to download a street network dataset.

# %% [markdown]
# <div class="alert alert-info">
#
# `osmnx` uses nominatim to geocode and find places. Make sure that the geography you search for is searchable here first:
#
# https://nominatim.openstreetmap.org/ui/search.html
#
# </div>

# %% [markdown]
# ## Import the libraries

# %%
# to download osm data
import osmnx as ox

# to import and explore data
import pandas as pd

# to manipulate and visualize spatial data
import geopandas as gpd

# to provide basemaps 
import contextily as ctx

# %% [markdown]
# ## Define an area of interest

# %%
address = 'Santa Monica, Los Angeles, CA'

# %%
# %%time
# %%time is a magic command to see how long it takes this cell to run 

# get the data from OSM that are tagged as 'building' for a 1000m X 1000m square area
# osm = ox.geometries_from_address(address,tags={'building':True},dist=1000)
osm = ox.geometries_from_address(address,tags={'building':True},dist=1000)
# Out:
# CPU times: user 905 ms, sys: 90.6 ms, total: 996 ms
# Wall time: 10.5 s

# %% [markdown]
# <div class="alert alert-danger">
#
# <h2>Be careful!</h2>
#
# Buildings are the "heaviest" data types to download, as they often encompass thousands of polygons. While you are technically capable of downloading buildings for entire neighborhoods and cities, doing so can easily overwhelm your notebook. Start small, and scale up!
# </div>

# %%
# how many rows and columns?
osm.shape
# Out:
# (4025, 58)

# %%
# what is the datatype?
type(osm)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# what are the columns and their datatypes?
osm.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 4025 entries, 0 to 4024
# Data columns (total 58 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   unique_id                    4025 non-null   object
#  1   osmid                        4025 non-null   int64
#  2   element_type                 4025 non-null   object
#  3   addr:state                   15 non-null     object
#  4   amenity                      18 non-null     object
#  5   building                     4025 non-null   object
#  6   ele                          3992 non-null   object
#  7   gnis:county_name             4 non-null      object
#  8   gnis:feature_id              6 non-null      object
#  9   gnis:import_uuid             4 non-null      object
#  10  gnis:reviewed                4 non-null      object
#  11  name                         37 non-null     object
#  12  source                       7 non-null      object
#  13  geometry                     4025 non-null   geometry
#  14  nodes                        4021 non-null   object
#  15  height                       3988 non-null   object
#  16  lacounty:ain                 3982 non-null   object
#  17  lacounty:bld_id              3988 non-null   object
#  18  leisure                      1 non-null      object
#  19  addr:housenumber             37 non-null     object
#  20  addr:postcode                19 non-null     object
#  21  addr:street                  26 non-null     object
#  22  designation                  3 non-null      object
#  23  opening_hours                6 non-null      object
#  24  shop                         10 non-null     object
#  25  start_date                   3834 non-null   object
#  26  website                      9 non-null      object
#  27  building:units               3438 non-null   object
#  28  office                       81 non-null     object
#  29  brand                        10 non-null     object
#  30  brand:wikidata               10 non-null     object
#  31  brand:wikipedia              10 non-null     object
#  32  cuisine                      2 non-null      object
#  33  takeaway                     2 non-null      object
#  34  dispensing                   1 non-null      object
#  35  healthcare                   2 non-null      object
#  36  addr:city                    16 non-null     object
#  37  old_name                     1 non-null      object
#  38  phone                        4 non-null      object
#  39  smoking                      1 non-null      object
#  40  wheelchair                   8 non-null      object
#  41  building:levels              5 non-null      object
#  42  building:levels:underground  1 non-null      object
#  43  alt_name                     1 non-null      object
#  44  building:use                 37 non-null     object
#  45  denomination                 1 non-null      object
#  46  religion                     1 non-null      object
#  47  operator                     1 non-null      object
#  48  addr:country                 1 non-null      object
#  49  tourism                      17 non-null     object
#  50  atm                          3 non-null      object
#  51  level                        1 non-null      object
#  52  drive_through                1 non-null      object
#  53  access                       1 non-null      object
#  54  parking                      1 non-null      object
#  55  emergency                    1 non-null      object
#  56  ways                         87 non-null     object
#  57  type                         87 non-null     object
# dtypes: geometry(1), int64(1), object(56)
# memory usage: 1.8+ MB

# %%
# show me the first 5 rows
osm.head()
# Out:
#         unique_id      osmid element_type addr:state           amenity  \
# 0  node/368166512  368166512         node         CA  community_centre
# 1  node/368166513  368166513         node         CA               NaN
# 2  node/368166514  368166514         node         CA               NaN
# 3  node/368172701  368172701         node         CA               NaN
# 4    way/30603660   30603660          way        NaN           parking
#
#   building   ele gnis:county_name gnis:feature_id  \
# 0      yes    37      Los Angeles         1693125
# 1      yes    33      Los Angeles         1693151
# 2      yes    32      Los Angeles         1693179
# 3      yes    40      Los Angeles         1693155
# 4      yes  46.1              NaN             NaN
#
#                        gnis:import_uuid  ... addr:country tourism  atm level  \
# 0  57871b70-0100-4405-bb30-88b2e001a944  ...          NaN     NaN  NaN   NaN
# 1  57871b70-0100-4405-bb30-88b2e001a944  ...          NaN     NaN  NaN   NaN
# 2  57871b70-0100-4405-bb30-88b2e001a944  ...          NaN     NaN  NaN   NaN
# 3  57871b70-0100-4405-bb30-88b2e001a944  ...          NaN     NaN  NaN   NaN
# 4                                   NaN  ...          NaN     NaN  NaN   NaN
#
#   drive_through access parking emergency ways type
# 0           NaN    NaN     NaN       NaN  NaN  NaN
# 1           NaN    NaN     NaN       NaN  NaN  NaN
# 2           NaN    NaN     NaN       NaN  NaN  NaN
# 3           NaN    NaN     NaN       NaN  NaN  NaN
# 4           NaN    NaN     NaN       NaN  NaN  NaN
#
# [5 rows x 58 columns]

# %%
# show me the last 5 rows
osm.tail()
# Out:
#              unique_id    osmid element_type addr:state amenity    building  \
# 4020  relation/6562471  6562471     relation        NaN     NaN       house
# 4021  relation/6562556  6562556     relation        NaN     NaN  apartments
# 4022  relation/6562558  6562558     relation        NaN     NaN       house
# 4023  relation/6563270  6563270     relation        NaN     NaN  commercial
# 4024  relation/6565066  6565066     relation        NaN     NaN  apartments
#
#        ele gnis:county_name gnis:feature_id gnis:import_uuid  ...  \
# 4020  57.5              NaN             NaN              NaN  ...
# 4021  62.8              NaN             NaN              NaN  ...
# 4022  73.9              NaN             NaN              NaN  ...
# 4023  43.6              NaN             NaN              NaN  ...
# 4024  42.9              NaN             NaN              NaN  ...
#
#      addr:country tourism  atm level drive_through access parking emergency  \
# 4020          NaN     NaN  NaN   NaN           NaN    NaN     NaN       NaN
# 4021          NaN     NaN  NaN   NaN           NaN    NaN     NaN       NaN
# 4022          NaN     NaN  NaN   NaN           NaN    NaN     NaN       NaN
# 4023          NaN     NaN  NaN   NaN           NaN    NaN     NaN       NaN
# 4024          NaN     NaN  NaN   NaN           NaN    NaN     NaN       NaN
#
#                         ways          type
# 4020  [440791987, 440791985]  multipolygon
# 4021  [440805052, 440805058]  multipolygon
# 4022  [440805054, 440805059]  multipolygon
# 4023  [440850305, 440850306]  multipolygon
# 4024  [440289106, 440978630]  multipolygon
#
# [5 rows x 58 columns]

# %%
# show me 10 random rows
osm.sample(10)
# Out:
#           unique_id      osmid element_type addr:state amenity    building  \
# 916   way/440285415  440285415          way        NaN     NaN  apartments
# 1274  way/440286804  440286804          way        NaN     NaN  apartments
# 283   way/421477578  421477578          way        NaN     NaN       house
# 2504  way/440291103  440291103          way        NaN     NaN  apartments
# 1384  way/440287501  440287501          way        NaN     NaN  apartments
# 277   way/421477555  421477555          way        NaN     NaN       house
# 655   way/421478945  421478945          way        NaN     NaN       house
# 2698  way/440291704  440291704          way        NaN     NaN       house
# 3302  way/440344404  440344404          way        NaN     NaN         yes
# 1961  way/440288512  440288512          way        NaN     NaN       house
#
#        ele gnis:county_name gnis:feature_id gnis:import_uuid  ...  \
# 916   51.3              NaN             NaN              NaN  ...
# 1274  53.4              NaN             NaN              NaN  ...
# 283   71.4              NaN             NaN              NaN  ...
# 2504  73.5              NaN             NaN              NaN  ...
# 1384  65.5              NaN             NaN              NaN  ...
# 277   65.6              NaN             NaN              NaN  ...
# 655   74.7              NaN             NaN              NaN  ...
# 2698  58.7              NaN             NaN              NaN  ...
# 3302  57.7              NaN             NaN              NaN  ...
# 1961  70.4              NaN             NaN              NaN  ...
#
#      addr:country tourism  atm level drive_through access parking emergency  \
# 916           NaN     NaN  NaN   NaN           NaN    NaN     NaN       NaN
# 1274          NaN     NaN  NaN   NaN           NaN    NaN     NaN       NaN
# 283           NaN     NaN  NaN   NaN           NaN    NaN     NaN       NaN
# 2504          NaN     NaN  NaN   NaN           NaN    NaN     NaN       NaN
# 1384          NaN     NaN  NaN   NaN           NaN    NaN     NaN       NaN
# 277           NaN     NaN  NaN   NaN           NaN    NaN     NaN       NaN
# 655           NaN     NaN  NaN   NaN           NaN    NaN     NaN       NaN
# 2698          NaN     NaN  NaN   NaN           NaN    NaN     NaN       NaN
# 3302          NaN     NaN  NaN   NaN           NaN    NaN     NaN       NaN
# 1961          NaN     NaN  NaN   NaN           NaN    NaN     NaN       NaN
#
#      ways type
# 916   NaN  NaN
# 1274  NaN  NaN
# 283   NaN  NaN
# 2504  NaN  NaN
# 1384  NaN  NaN
# 277   NaN  NaN
# 655   NaN  NaN
# 2698  NaN  NaN
# 3302  NaN  NaN
# 1961  NaN  NaN
#
# [10 rows x 58 columns]

# %% [markdown]
# ## Eliminate unnecessary columns
# The dataframe has 58 columns. Let's explore what these are, and which ones are necessary for our use.

# %%
# Get a full list of columns
list(osm)
# Out:
# ['unique_id',
#  'osmid',
#  'element_type',
#  'addr:state',
#  'amenity',
#  'building',
#  'ele',
#  'gnis:county_name',
#  'gnis:feature_id',
#  'gnis:import_uuid',
#  'gnis:reviewed',
#  'name',
#  'source',
#  'geometry',
#  'nodes',
#  'height',
#  'lacounty:ain',
#  'lacounty:bld_id',
#  'leisure',
#  'addr:housenumber',
#  'addr:postcode',
#  'addr:street',
#  'designation',
#  'opening_hours',
#  'shop',
#  'start_date',
#  'website',
#  'building:units',
#  'office',
#  'brand',
#  'brand:wikidata',
#  'brand:wikipedia',
#  'cuisine',
#  'takeaway',
#  'dispensing',
#  'healthcare',
#  'addr:city',
#  'old_name',
#  'phone',
#  'smoking',
#  'wheelchair',
#  'building:levels',
#  'building:levels:underground',
#  'alt_name',
#  'building:use',
#  'denomination',
#  'religion',
#  'operator',
#  'addr:country',
#  'tourism',
#  'atm',
#  'level',
#  'drive_through',
#  'access',
#  'parking',
#  'emergency',
#  'ways',
#  'type']

# %% [markdown]
# What are the datatypes and count of null values?

# %%
osm.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 4025 entries, 0 to 4024
# Data columns (total 58 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   unique_id                    4025 non-null   object
#  1   osmid                        4025 non-null   int64
#  2   element_type                 4025 non-null   object
#  3   addr:state                   15 non-null     object
#  4   amenity                      18 non-null     object
#  5   building                     4025 non-null   object
#  6   ele                          3992 non-null   object
#  7   gnis:county_name             4 non-null      object
#  8   gnis:feature_id              6 non-null      object
#  9   gnis:import_uuid             4 non-null      object
#  10  gnis:reviewed                4 non-null      object
#  11  name                         37 non-null     object
#  12  source                       7 non-null      object
#  13  geometry                     4025 non-null   geometry
#  14  nodes                        4021 non-null   object
#  15  height                       3988 non-null   object
#  16  lacounty:ain                 3982 non-null   object
#  17  lacounty:bld_id              3988 non-null   object
#  18  leisure                      1 non-null      object
#  19  addr:housenumber             37 non-null     object
#  20  addr:postcode                19 non-null     object
#  21  addr:street                  26 non-null     object
#  22  designation                  3 non-null      object
#  23  opening_hours                6 non-null      object
#  24  shop                         10 non-null     object
#  25  start_date                   3834 non-null   object
#  26  website                      9 non-null      object
#  27  building:units               3438 non-null   object
#  28  office                       81 non-null     object
#  29  brand                        10 non-null     object
#  30  brand:wikidata               10 non-null     object
#  31  brand:wikipedia              10 non-null     object
#  32  cuisine                      2 non-null      object
#  33  takeaway                     2 non-null      object
#  34  dispensing                   1 non-null      object
#  35  healthcare                   2 non-null      object
#  36  addr:city                    16 non-null     object
#  37  old_name                     1 non-null      object
#  38  phone                        4 non-null      object
#  39  smoking                      1 non-null      object
#  40  wheelchair                   8 non-null      object
#  41  building:levels              5 non-null      object
#  42  building:levels:underground  1 non-null      object
#  43  alt_name                     1 non-null      object
#  44  building:use                 37 non-null     object
#  45  denomination                 1 non-null      object
#  46  religion                     1 non-null      object
#  47  operator                     1 non-null      object
#  48  addr:country                 1 non-null      object
#  49  tourism                      17 non-null     object
#  50  atm                          3 non-null      object
#  51  level                        1 non-null      object
#  52  drive_through                1 non-null      object
#  53  access                       1 non-null      object
#  54  parking                      1 non-null      object
#  55  emergency                    1 non-null      object
#  56  ways                         87 non-null     object
#  57  type                         87 non-null     object
# dtypes: geometry(1), int64(1), object(56)
# memory usage: 1.8+ MB

# %% [markdown]
# Really, what we need is just...

# %%
# subset it

# create a list of column names you want to keep
columns_to_keep = ['geometry','building']

# redefine the dataframe based on only the columns we want to keep 
osm = osm[columns_to_keep]

# output 10 random rows
osm.sample(10)
# Out:
#                                                geometry    building
# 398   POLYGON ((-118.49866 34.03387, -118.49871 34.0...       house
# 3681  POLYGON ((-118.48896 34.03391, -118.48886 34.0...  apartments
# 2039  POLYGON ((-118.49669 34.01985, -118.49666 34.0...      retail
# 2154  POLYGON ((-118.49054 34.01704, -118.49066 34.0...  commercial
# 3064  POLYGON ((-118.49814 34.01802, -118.49808 34.0...      retail
# 3192  POLYGON ((-118.49125 34.02446, -118.49116 34.0...  commercial
# 1128  POLYGON ((-118.49820 34.02606, -118.49832 34.0...  apartments
# 3402  POLYGON ((-118.49203 34.02833, -118.49200 34.0...  apartments
# 174   POLYGON ((-118.48599 34.01780, -118.48573 34.0...         yes
# 2908  POLYGON ((-118.50515 34.02113, -118.50514 34.0...       house

# %% [markdown]
# # Make a building type chart
# ## Count the unique buildings
#
# The `.value_counts()` command allows us to filter a column by distinct values, and provides a count.

# %%
# assign a new variable for building counts
osm_building_counts = osm.building.value_counts()

# output the results
osm_building_counts
# Out:
# house           1684
# apartments      1339
# residential      327
# retail           226
# commercial       216
# yes              158
# industrial        20
# school            19
# hotel             18
# warehouse          6
# garage             4
# hospital           4
# kindergarten       3
# college            1
# Name: building, dtype: int64

# %% [markdown]
# ## Create a dataframe from value counts
# Let's create a dataframe for building types. Currently, value counts returns a series, which is a one-dimensional array, essentially, a single column in a table.

# %%
type(osm_building_counts)
# Out:
# pandas.core.series.Series

# %%
# create a new variable and convert it into a pandas dataframe
df_osm_building_types = pd.DataFrame(osm_building_counts)

# what does the dataframe look like?
df_osm_building_types
# Out:
#               building
# house             1684
# apartments        1339
# residential        327
# retail             226
# commercial         216
# yes                158
# industrial          20
# school              19
# hotel               18
# warehouse            6
# garage               4
# hospital             4
# kindergarten         3
# college              1

# %% [markdown]
# The dataframe created has the building type (in bold) as the index. Let's reset the index.

# %%
# reset the index
df_osm_building_types = df_osm_building_types.reset_index()
df_osm_building_types
# Out:
#            index  building
# 0          house      1684
# 1     apartments      1339
# 2    residential       327
# 3         retail       226
# 4     commercial       216
# 5            yes       158
# 6     industrial        20
# 7         school        19
# 8          hotel        18
# 9      warehouse         6
# 10        garage         4
# 11      hospital         4
# 12  kindergarten         3
# 13       college         1

# %% [markdown]
# ## Renaming columns
#
# We can rename the columns by using the `.columns` command to reset it based on a list we provide.

# %%
df_osm_building_types.columns = ['building_type','count']
df_osm_building_types
# Out:
#    building_type  count
# 0          house   1684
# 1     apartments   1339
# 2    residential    327
# 3         retail    226
# 4     commercial    216
# 5            yes    158
# 6     industrial     20
# 7         school     19
# 8          hotel     18
# 9      warehouse      6
# 10        garage      4
# 11      hospital      4
# 12  kindergarten      3
# 13       college      1

# %% [markdown]
# ## Create a horizontal bar chart
#
# First, let's plot it and see what happens:

# %%
df_osm_building_types.plot()

# %% [markdown]
# What is it doing? What does it choose to plot by default?
#
# Let's change this by specifying a horizontal bar graph `.barh` and adding arguments for size `figsize` and `x`:

# %%
df_osm_building_types.plot.barh(figsize=(12,6),
                                x='building_type')

# %% [markdown]
# ## Sorting a dataframe

# %% [markdown]
# oops! A horizontal bar reverses the order of the values on the y axis. Let's fix that by sorting our dataframe using the `.sort_values` command.

# %%
# sort it the other way
df_osm_building_types = df_osm_building_types.sort_values(by='count', ascending=True)
df_osm_building_types
# Out:
#    building_type  count
# 13       college      1
# 12  kindergarten      3
# 10        garage      4
# 11      hospital      4
# 9      warehouse      6
# 8          hotel     18
# 7         school     19
# 6     industrial     20
# 5            yes    158
# 4     commercial    216
# 3         retail    226
# 2    residential    327
# 1     apartments   1339
# 0          house   1684

# %% [markdown]
# Now output it again, but this time, add a title, and only show the "Top 10"

# %%
df_osm_building_types[-10:].plot.barh(figsize=(12,4),
                                      x='building_type',
                                      y='count',
                                      title="Top 10 building types in "+address)

# %% [markdown]
# <div class="alert alert-info">
#
# Now it's your turn! Search for an area of interest, anywhere in the world, and create a horizontal bar plot of building types.
#
# Right click on the resulting image, and paste it into this <a href="https://docs.google.com/document/d/1e-gO10bThpJ316h6M-B-iASQ0xkbXP1HyTp_80C0sTI/edit?usp=sharing" target="_blank">Google Document</a>.
# </div>

# %% [markdown]
# # Geopandas Map Plots
#
# Let's return to the original OSM data we downloaded. Remember that the OSMnx `geometries_from_address` command returned a geodataframe of buildings. Let's plot them:

# %%
# check the data type
type(osm)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# plot entire dataset
ax = osm.plot(figsize=(10,10))

# %%
# plot a single random building
ax = osm.sample(1).plot()

# %% [markdown]
# ## Color coding buildings
# Use the `column` argument to assign a column in the dataframe to color the polygons. If the column is numerical, it will poduce a numerically sequential map. If the column is categorical, it will produce a categorically colored map (a different color assigned to each distinct category).
#
# You can use the `cmap` argument to assign a color palette. Find all the available options for `cmap` here:
# - https://matplotlib.org/3.1.1/gallery/color/colormap_reference.html

# %%
ax = osm.plot(figsize=(10,10),
         column='building',
         cmap='tab20',
         legend=True)

# %% [markdown]
# ## Clean up: Add a title, move the legend, remove axis
#
# ### Move the legend
#
# Moving the legend is surprisingly difficult to do. There are two key/value pairs that you need to pass using the `legend_kwds` argument. The `loc` and `bbox_to_anchor` values allow you to locate the legend outside the plot. Here is a good explanation of how that is done:
#
# * https://stackoverflow.com/questions/4700614/how-to-put-the-legend-out-of-the-plot/43439132#43439132
#
# ### Remove the legend's border
# Inside `legend_kwds`, you can add the argument for `frameon` to be False.
#
# ### Add a title
# Use `ax.set_title()` to add a title to the chart.
#
# ### Remove the axis
#
# Turn off the axis with the `ax.axis('off')` statement.

# %%
# create the map plot
ax = osm.plot(figsize=(10,10),
         column='building',
         cmap='tab20',
         legend=True,
         legend_kwds={'loc':'upper left','bbox_to_anchor':(1,1),'frameon':False})

# additional attributes to the map plot

# add a title
ax.set_title('Building types in ' + address)

# get rid of the axis
ax.axis('off')
# Out:
# (-118.509151255, -118.48394684499998, 34.01444251, 34.03537528999999)

# %% [markdown]
# ## Add a basemap
#
# Adding a basemap to a geopandas plot can be done using the contextily library. To do so, you must:
#
# * reproject your geodataframe to Web Mercator (epsg: 3857)
# * add a basemap, use the following guidelines: https://github.com/geopandas/contextily

# %%
# reproject to Web Mercator
osm_web_mercator = osm.to_crs(epsg=3857)

# %%
ax = osm_web_mercator.plot(figsize=(10,10),
                            column='building',
                            cmap='tab20',
                            legend=True,
                            legend_kwds={'loc':'upper left','bbox_to_anchor':(1,1),'frameon':False})

# add the basemap

# open street map basemap
# ctx.add_basemap(ax,source=ctx.providers.OpenStreetMap.Mapnik)

# basemap from carto that has a dark background (easier to see)
ctx.add_basemap(ax,source=ctx.providers.CartoDB.DarkMatter)

# %% [markdown]
# <div class="alert alert-info">
# Now it's your turn! Create a colored geopandas map of your area of interest, and post your results in this <a href="https://docs.google.com/document/d/1e-gO10bThpJ316h6M-B-iASQ0xkbXP1HyTp_80C0sTI/edit?usp=sharing" target="_blank">Google Document</a>.
# </div>

# %% [markdown]
# # Create a function
#
# Whew! That was a lot of work to finally get our building map for a given location. But what if you wanted to repeat this process for *multiple* locations?
#
# Welcome to the world of functions. According to [W3Schools](https://www.w3schools.com/python/python_functions.asp), a python function is:
# * A function is a block of code which only runs when it is called.
# * You can pass data, known as parameters, into a function.
# * A function can return data as a result.
#
# In other words, you create a function (a block of code that does something), and it remains dormant until you call on it. For this lab, let's create a function that creates a building map based on location data that you pass into it.

# %%
# let's make a function together

# %%
# here is the function
def make_building_map(location):
    # get the data from osm
    osm = ox.geometries_from_address(location,
                                     tags={'building':True},
                                     dist=1000)
    
    # reproject to Web Mercator
    osm_web_mercator = osm.to_crs(epsg=3857)
    
    # create the map
    ax = osm_web_mercator.plot(figsize=(10,10),
                                column='building',
                                cmap='tab20',
                                legend=True,
                                legend_kwds={'loc':'upper left','bbox_to_anchor':(1,1),'frameon':False})
    
    # additional features

    # add a title
    ax.set_title('Building types in ' + location)

    # get rid of the axis
    ax.axis('off')
    
    # add a dark basemap
    ctx.add_basemap(ax,source=ctx.providers.CartoDB.DarkMatter)

# %%
# %%time
# run the function once
make_building_map('USC, Los Angeles, California, USA')
# Out:
# CPU times: user 1.65 s, sys: 228 ms, total: 1.88 s
# Wall time: 13.4 s

# %% [markdown]
# # Looping through it
#
# To make the use of functions even more effective, let's create a list of addresses.

# %%
address_list = ['UCLA, Los Angeles, California, USA','USC, Los Angeles, California, USA']

# %%
# %%time
# run our function for every address in our list
for address in address_list:
    make_building_map(address)
# Out:
# CPU times: user 3.54 s, sys: 428 ms, total: 3.97 s
# Wall time: 19.6 s

# %% [markdown]
# # Doing other searches
#
# For this lab, we used the tags argument: `'building':True`. This indicates a desire to download *all* buildings for the given geography. There are many other options to filter what you download from OSM.
#
# * https://wiki.openstreetmap.org/wiki/Map_Features
#
# Examples calls to intake features from OSM:
#
# ```python
# # for all buildings (could be a very large query)
# features = ox.geometries_from_address(place, tags={'building': True})
#
# # for specific buildings
# features = ox.geometries_from_address(place, tags={'building': ['retail','industrial','commercial']})
#
# # for amenities
# features = ox.geometries_from_address(place, tags={'amenity': ['restaurant','fast_food']})
#
# # for leisure spaces
# features = ox.geometries_from_address(place, tags={'leisure': ['park']})
# ```
#
# Note that when you perform a different search based on a different type of tag, **you may not get the same columns back**. You will need to adjust the code in this lab to reflect the columns that are returned. For example, a tag for "leisure" may not return "buildings", and instead, you may want to color code the map by the column "leisure."
